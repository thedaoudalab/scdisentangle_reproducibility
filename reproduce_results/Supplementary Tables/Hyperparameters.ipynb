# %%
rows = [
    ("Hyperparameter", "Perturbation prediction", "Latent structure analysis"),
    ("Latent factors", "16", "16"),
    ("Initial encoder", "[n_genes, 256, 16]", "[n_genes, 256, 16]"),
    ("Residual encoder", "[16, 256, 1]", "[16, 256, 1]"),
    ("Covariate mapper", "[1, 256, 16]", "[1, 256, 16]"),
    ("Activation (all MLPs)", "Sinusoidal (Sine)", "Sinusoidal (Sine)"),
    ("Weight initialization", "Xavier", "Xavier"),
    ("Batch normalization", "None", "None"),
    ("DecoderSCVI layers", "3", "3"),
    ("DecoderSCVI hidden size", "1,024", "256"),
    ("DecoderSCVI batch/layer norm", "None", "None"),
    ("Likelihood", "Negative Binomial", "Negative Binomial"),
    ("Optimizer", "AdamW", "AdamW"),
    ("Weight decay", "0.01", "0.01"),
    ("Gradient clipping (max norm)", "1.0", "1.0"),
    ("Initial encoder + Decoder learning rate", "1 × 10⁻⁴", "1 × 10⁻⁴"),
    ("Residual encoder + Mapper learning rate", "1 × 10⁻³", "1 × 10⁻³"),
    ("Embedder learning rate", "1 × 10⁻³", "1 × 10⁻³"),
    ("λ_rec (reconstruction loss weight)", "1 × 10⁻⁵", "1 × 10⁻⁵"),
    ("λ_latent (latent recovery loss weight)", "2 × 10⁻³", "2 × 10⁻³"),
    ("Batch size", "128", "128"),
    ("Training epochs", "521", "521"),
    ("Checkpoint criterion", "R² Mean (top 10 DEGs)", "MIG (binned)"),
]

# %%
print("=" * 100)
print("COPY-PASTE INTO GOOGLE SHEETS (tab-separated)")
print("=" * 100)
print()
for row in rows:
    print("\t".join(row))

print()
print()
print("=" * 100)
print("COPY-PASTE INTO GOOGLE DOCS (pipe-separated, for manual table)")
print("=" * 100)
print()
for row in rows:
    print(" | ".join(row))

print()
print()

# Now the dataset-specific embedder details — as a separate small table
print("=" * 100)
print("DATASET-SPECIFIC: Covariate embedder dimensions (tab-separated)")
print("=" * 100)
print()

emb_rows = [
    ("Dataset", "Task", "Observed covariate", "Categories (C)", "Embedding dim (d)"),
    ("Kang", "Perturbation", "condition (IFN-β status)", "2", "2"),
    ("Kang", "Perturbation", "cell_type", "8", "2"),
    ("Kang", "Latent structure", "condition (IFN-β status)", "2", "2"),
    ("Afriat (infected)", "Perturbation", "infected", "2", "2"),
    ("Afriat (infected)", "Perturbation", "zone", "2", "2"),
    ("Afriat (HPI)", "Perturbation", "status_control", "3", "2"),
    ("Afriat (HPI)", "Perturbation", "zone", "2", "2"),
    ("Afriat (HPI)", "Perturbation", "coarse_time", "6", "2"),
    ("Norman", "Perturbation", "condition (perturbation)", "232", "8"),
    ("Blum", "Perturbation", "tissue", "2", "2"),
    ("Blum", "Perturbation", "donor", "12", "4"),
    ("Karthaus", "Perturbation", "time (C/R stage)", "11", "3"),
    ("Karthaus", "Latent structure", "time (C/R stage)", "11", "3"),
    ("Hao", "Latent structure", "donor", "8", "2"),
    ("Guerrero", "Latent structure", "Sample_id", "10", "3"),
]

for row in emb_rows:
    print("\t".join(row))

print()
print()

# Also pipe version
print("=" * 100)
print("DATASET-SPECIFIC: Covariate embedder dimensions (pipe-separated)")
print("=" * 100)
print()
for row in emb_rows:
    print(" | ".join(row))

print("\n\nDONE")
# Out:
# ...
#
# Hyperparameter	Perturbation prediction	Latent structure analysis
# Latent factors	16	16
# Initial encoder	[n_genes, 256, 16]	[n_genes, 256, 16]
# Residual encoder	[16, 256, 1]	[16, 256, 1]
# Covariate mapper	[1, 256, 16]	[1, 256, 16]
# Activation (all MLPs)	Sinusoidal (Sine)	Sinusoidal (Sine)
# Weight initialization	Xavier	Xavier
# Batch normalization	None	None
# DecoderSCVI layers	3	3
# DecoderSCVI hidden size	1,024	256
# DecoderSCVI batch/layer norm	None	None
# Likelihood	Negative Binomial	Negative Binomial
# Optimizer	AdamW	AdamW
# Weight decay	0.01	0.01
# Gradient clipping (max norm)	1.0	1.0
# Initial encoder + Decoder learning rate	1 × 10⁻⁴	1 × 10⁻⁴
# Residual encoder + Mapper learning rate	1 × 10⁻³	1 × 10⁻³
# Embedder learning rate	1 × 10⁻³	1 × 10⁻³
# λ_rec (reconstruction loss weight)	1 × 10⁻⁵	1 × 10⁻⁵
# λ_latent (latent recovery loss weight)	2 × 10⁻³	2 × 10⁻³
# Batch size	128	128
# Training epochs	521	521
# Checkpoint criterion	R² Mean (top 10 DEGs)	MIG (binned)
#
#
# ...
